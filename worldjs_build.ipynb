# %%
# !mkdir workspace
# !ls
# Out:
# sample_data  workspace

# %%
# %cd ./workspace/
# !ls
# Out:
# /content/workspace

# %%
# !git clone https://github.com/emscripten-core/emsdk.git
# Out:
# Cloning into 'emsdk'...
# remote: Enumerating objects: 4382, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 4382 (delta 4), reused 5 (delta 2), pack-reused 4372 (from 2)
# Receiving objects: 100% (4382/4382), 2.44 MiB | 8.70 MiB/s, done.
# Resolving deltas: 100% (2889/2889), done.

# %%
# %cd emsdk
# Out:
# /content/workspace/emsdk

# %%
# !./emsdk install latest
# Out:
# Resolving SDK alias 'latest' to '4.0.2'
# Resolving SDK version '4.0.2' to 'sdk-releases-cc8eba40de8235f9c33d92463018f87b3edaa09e-64bit'
# Installing SDK 'sdk-releases-cc8eba40de8235f9c33d92463018f87b3edaa09e-64bit'..
# Installing tool 'node-20.18.0-64bit'..
# Downloading: /content/workspace/emsdk/downloads/node-v20.18.0-linux-x64.tar.xz from https://storage.googleapis.com/webassembly/emscripten-releases-builds/deps/node-v20.18.0-linux-x64.tar.xz, 25738964 Bytes
# Unpacking '/content/workspace/emsdk/downloads/node-v20.18.0-linux-x64.tar.xz' to '/content/workspace/emsdk/node/20.18.0_64bit'
# Done installing tool 'node-20.18.0-64bit'.
# Installing tool 'releases-cc8eba40de8235f9c33d92463018f87b3edaa09e-64bit'..
# Downloading: /content/workspace/emsdk/downloads/cc8eba40de8235f9c33d92463018f87b3edaa09e-wasm-binaries.tar.xz from https://storage.googleapis.com/webassembly/emscripten-releases-builds/linux/cc8eba40de8235f9c33d92463018f87b3edaa09e/wasm-binaries.tar.xz, 310937544 Bytes
# ...

# %%
# !./emsdk activate latest
# Out:
# Resolving SDK alias 'latest' to '4.0.2'
# Resolving SDK version '4.0.2' to 'sdk-releases-cc8eba40de8235f9c33d92463018f87b3edaa09e-64bit'
# Setting the following tools as active:
#    node-20.18.0-64bit
#    releases-cc8eba40de8235f9c33d92463018f87b3edaa09e-64bit
#
# Next steps:
# - To conveniently access emsdk tools from the command line,
#   consider adding the following directories to your PATH:
#     /content/workspace/emsdk
#     /content/workspace/emsdk/upstream/emscripten
# - This can be done for the current shell by running:
#     source "/content/workspace/emsdk/emsdk_env.sh"
# - Configure emsdk in your shell startup scripts by running:
#     echo 'source "/content/workspace/emsdk/emsdk_env.sh"' >> $HOME/.bash_profile

# %%
# %cd ../
# Out:
# /content/workspace

# %%
# !git clone -b EXPORT_ES6 https://github.com/delta-kimigatame/World.git
# Out:
# Cloning into 'World'...
# remote: Enumerating objects: 2586, done.
# remote: Counting objects: 100% (399/399), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 2586 (delta 329), reused 300 (delta 278), pack-reused 2187 (from 1)
# Receiving objects: 100% (2586/2586), 2.48 MiB | 11.30 MiB/s, done.
# Resolving deltas: 100% (1541/1541), done.

# %%
# %cd World/
# Out:
# /content/workspace/World

# %%
# !git submodule init
# Out:
# Submodule 'lib/WorldCMake' (https://github.com/mmorise/World.git) registered for path 'lib/WorldCMake'

# %%
# !git submodule update
# Out:
# Cloning into '/content/workspace/World/lib/WorldCMake'...
# Submodule path 'lib/WorldCMake': checked out '2c9d3030bf04516bdc19c0afa1ea5571eaaa2c59'

# %%
# !npm install -g typescript
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 1 package in 2s
# ⠴

# %%
# !mkdir build

# %%
# %cd build
# Out:
# /content/workspace/World/build

# %%
# !cmake -DCMAKE_TOOLCHAIN_FILE=/content/workspace/emsdk/upstream/emscripten/cmake/Modules/Platform/Emscripten.cmake -DCMAKE_BUILD_TYPE=Release ..
# Out:
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 3.10 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value.  Or, use the <min>...<max> syntax
#   to tell CMake that the project requires at least <min> but has been updated
#   to work with policies introduced by <max> or earlier.
#
#
# CMake Deprecation Warning at lib/WorldCMake/CMakeLists.txt:15 (cmake_minimum_required):
#   Compatibility with CMake < 3.10 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value.  Or, use the <min>...<max> syntax
#   to tell CMake that the project requires at least <min> but has been updated
#   to work with policies introduced by <max> or earlier.
#
#
# -- Configuring done (1.4s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/workspace/World/build

# %%
# !make
# Out:
# [  4%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/cheaptrick.cpp.o
# shared:INFO: (Emscripten: Running sanity checks)
# [  8%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/codec.cpp.o
# [ 12%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/common.cpp.o
# [ 16%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/d4c.cpp.o
# [ 20%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/dio.cpp.o
# [ 24%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/fft.cpp.o
# [ 28%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/harvest.cpp.o
# [ 32%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/matlabfunctions.cpp.o
# [ 36%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/stonemask.cpp.o
# [ 40%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/synthesis.cpp.o
# [ 44%] Building CXX object lib/WorldCMake/CMakeFiles/world.dir/src/synthesisrealtime.cpp.o
# ...

# %%
# !ls
# Out:
# CMakeCache.txt	cmake_install.cmake  libWav2World.a  WorldJS.d.ts  WorldJS.wasm
# CMakeFiles	lib		     Makefile	     WorldJS.js

# %%
# !cat WorldJs.d.ts
# Out:
# cat: WorldJs.d.ts: No such file or directory

# %%
# %cd ../
# Out:
# /content/workspace/World

# %%
# !zip -r World_JS.zip build/
# Out:
#   adding: build/ (stored 0%)
#   adding: build/WorldJS.js (deflated 76%)
#   adding: build/cmake_install.cmake (deflated 66%)
#   adding: build/WorldJS.wasm (deflated 72%)
#   adding: build/WorldJS.d.ts (deflated 77%)
#   adding: build/Makefile (deflated 85%)
#   adding: build/CMakeCache.txt (deflated 81%)
#   adding: build/libWav2World.a (deflated 59%)
#   adding: build/CMakeFiles/ (stored 0%)
#   adding: build/CMakeFiles/3.31.4/ (stored 0%)
#   adding: build/CMakeFiles/3.31.4/CMakeCCompiler.cmake (deflated 71%)
#   adding: build/CMakeFiles/3.31.4/CMakeSystem.cmake (deflated 53%)
#   adding: build/CMakeFiles/3.31.4/CMakeCXXCompiler.cmake (deflated 74%)
#   adding: build/CMakeFiles/WorldJS.dir/ (stored 0%)
#   adding: build/CMakeFiles/WorldJS.dir/progress.make (deflated 58%)
#   adding: build/CMakeFiles/WorldJS.dir/flags.make (deflated 21%)
#   adding: build/CMakeFiles/WorldJS.dir/linkLibs.rsp (deflated 56%)
#   adding: build/CMakeFiles/WorldJS.dir/link.txt (deflated 38%)
# ...
